# %%
from IPython.display import Image
Image(filename='summary.png')

# %%
# strings
# "..." or '...'
# ordered and indexable (by number)
# immutable
strg = "amy bob cathy dan erica"
print (strg, len(strg), strg[4])
#strg[4] = 'B'
# Out:
# amy bob cathy dan erica 23 b

# %%
# lists
# [...]
# ordered and indexable (by number)
# mutable
lst = ['amy', 'bob', 'cathy', 'dan', 'erica']
print (lst, len(lst), lst[4])
lst[1] = 'Bob'
print (lst)
lst.append('fey')
print (lst)
del lst[1]
print (lst)
# Out:
# ['amy', 'bob', 'cathy', 'dan', 'erica'] 5 erica
# ['amy', 'Bob', 'cathy', 'dan', 'erica']
# ['amy', 'Bob', 'cathy', 'dan', 'erica', 'fey']
# ['amy', 'cathy', 'dan', 'erica', 'fey']

# %%
# tuples
# (...)
# ordered and indexable (by number)
# immutable
tup = ('amy', 'bob', 'cathy', 'dan', 'erica')
print (tup, len(tup), tup[4])
#tup[2] = 'Bob'
# Out:
# ('amy', 'bob', 'cathy', 'dan', 'erica') 5 erica

# %%
# ranges 
# range(start, end, step)
# ordered and indexable (by number)
rng = range(0, 10, 2)
print (rng, list(rng), len(rng), rng[4])
# Out:
# range(0, 10, 2) [0, 2, 4, 6, 8] 5 8

# %%
# sets
# {...}
# unordered and not indexable
# mutable
# deduped
st = {'amy', 'bob', 'bob', 'cathy', 'dan', 'erica'}
print (st, len(st))
#print (st[4])
st.add('fey')
print (st)
st.remove('bob')
print (st)
# Out:
# {'dan', 'erica', 'cathy', 'amy', 'bob'} 5
# {'dan', 'erica', 'cathy', 'amy', 'bob', 'fey'}
# {'dan', 'erica', 'cathy', 'amy', 'fey'}

# %%
# dictionaries
# {k:v}
# unordered and indexable (by key)
# key unique and immutable, value mutable
dd = {'amy':10, 'bob':30, 'cathy':40, 'dan':50, 'erica':60}
print (dd, len(dd), dd['dan'])
dd['bob'] = 3
print (dd)
dd['fey'] = 60
print (dd)
del dd['amy']
print (dd)
# Out:
# {'amy': 10, 'bob': 30, 'cathy': 40, 'dan': 50, 'erica': 60} 5 50
# {'amy': 10, 'bob': 3, 'cathy': 40, 'dan': 50, 'erica': 60}
# {'amy': 10, 'bob': 3, 'cathy': 40, 'dan': 50, 'erica': 60, 'fey': 60}
# {'bob': 3, 'cathy': 40, 'dan': 50, 'erica': 60, 'fey': 60}
